# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from Assignment 1. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D) # (2, 15)
y = np.random.randint(C, size=(N,)) # (10, (2,))

for reg in [0, 3.14]: # reg: 0, 3.14
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2], # (20, 30)
        input_dim=D, # 15
        num_classes=C, # 10
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.   
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2.3004790897684924
# W1 relative error: 1.4839894979053162e-07
# W2 relative error: 0.00020570303546030993
# W3 relative error: 4.598704810500674e-07
# b1 relative error: 5.376386325179258e-09
# b2 relative error: 2.085653896836184e-09
# b3 relative error: 7.661812651176767e-11
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 4.845344814614926e-09
# W2 relative error: 6.86942277940646e-08
# W3 relative error: 2.131129848945024e-08
# b1 relative error: 1.4752427965311745e-08
# b2 relative error: 1.7223751746766738e-09
# b3 relative error: 2.6095787025091476e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

# 가중치의 무작위 초기화에 대한 표준편차를 제공하는 스칼라 값
weight_scale = 1e-2   # Experiment with this!
learning_rate = 1e-2  # Experiment with this!

# FullyConnectedNet: cs231n/classifier/fc_net.py
model = FullyConnectedNet(
    # 2 layers
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 2.355489
# (Epoch 0 / 20) train acc: 0.280000; val_acc: 0.103000
# (Epoch 1 / 20) train acc: 0.380000; val_acc: 0.116000
# (Epoch 2 / 20) train acc: 0.580000; val_acc: 0.119000
# (Epoch 3 / 20) train acc: 0.560000; val_acc: 0.157000
# (Epoch 4 / 20) train acc: 0.580000; val_acc: 0.167000
# (Epoch 5 / 20) train acc: 0.660000; val_acc: 0.186000
# (Iteration 11 / 40) loss: 1.262809
# (Epoch 6 / 20) train acc: 0.540000; val_acc: 0.157000
# (Epoch 7 / 20) train acc: 0.600000; val_acc: 0.163000
# (Epoch 8 / 20) train acc: 0.780000; val_acc: 0.179000
# (Epoch 9 / 20) train acc: 0.800000; val_acc: 0.202000
# (Epoch 10 / 20) train acc: 0.960000; val_acc: 0.212000
# (Iteration 21 / 40) loss: 0.411190
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.200000
# (Epoch 12 / 20) train acc: 0.960000; val_acc: 0.199000
# (Epoch 13 / 20) train acc: 0.980000; val_acc: 0.200000
# (Epoch 14 / 20) train acc: 0.960000; val_acc: 0.201000
# (Epoch 15 / 20) train acc: 0.980000; val_acc: 0.205000
# (Iteration 31 / 40) loss: 0.066318
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.214000
# (Epoch 17 / 20) train acc: 0.980000; val_acc: 0.213000
# (Epoch 18 / 20) train acc: 0.960000; val_acc: 0.214000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.213000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.213000

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 5e-2   # Experiment with this!
learning_rate = 1e-2  # Experiment with this!

model = FullyConnectedNet(
    # 5 layers
    [100, 100, 100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 3.556615
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.107000
# (Epoch 1 / 20) train acc: 0.280000; val_acc: 0.130000
# (Epoch 2 / 20) train acc: 0.540000; val_acc: 0.141000
# (Epoch 3 / 20) train acc: 0.760000; val_acc: 0.141000
# (Epoch 4 / 20) train acc: 0.740000; val_acc: 0.126000
# (Epoch 5 / 20) train acc: 0.820000; val_acc: 0.136000
# (Iteration 11 / 40) loss: 0.869724
# (Epoch 6 / 20) train acc: 0.960000; val_acc: 0.142000
# (Epoch 7 / 20) train acc: 0.960000; val_acc: 0.144000
# (Epoch 8 / 20) train acc: 0.960000; val_acc: 0.146000
# (Epoch 9 / 20) train acc: 0.960000; val_acc: 0.147000
# (Epoch 10 / 20) train acc: 0.980000; val_acc: 0.150000
# (Iteration 21 / 40) loss: 0.213163
# (Epoch 11 / 20) train acc: 0.980000; val_acc: 0.156000
# (Epoch 12 / 20) train acc: 0.980000; val_acc: 0.158000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.138000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.138000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.143000
# (Iteration 31 / 40) loss: 0.109936
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.145000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.143000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.150000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.153000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.152000

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# [설정값]
# 1. 3-layers: weight_scale 1e-2/ learning_rate 1e-2
# 2. 5-layers: weight_scale 5e-2/ learning_rate 1e-2
#
# [레이어가 깊어짐에 따라 3-layer network보다 더 큰 Weight scale이 필요. 초깃값이 너무 작으면 weight가 계수로 곱해지는 경사값도 너무 작아져 학습이 제대로 발생하지 않음. 너무 크면 폭발, 작으면 소실하는 문제점이 있어서 5-layer network가 가중치 초기화 값에 더 예민하다고 볼 수 있음. learning rate는 같게 설정해도 똑같이 수렴하였지만, 더 큰 가중치 초기화 값을 사용할 때 더 큰 학습률이 필요함]

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")
    
for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 2.892937
# (Epoch 0 / 5) train acc: 0.146000; val_acc: 0.133000
# (Iteration 11 / 200) loss: 2.331475
# (Iteration 21 / 200) loss: 2.102751
# (Iteration 31 / 200) loss: 2.089727
# (Epoch 1 / 5) train acc: 0.262000; val_acc: 0.226000
# (Iteration 41 / 200) loss: 2.105482
# (Iteration 51 / 200) loss: 1.972161
# (Iteration 61 / 200) loss: 1.953659
# (Iteration 71 / 200) loss: 2.060991
# (Epoch 2 / 5) train acc: 0.317000; val_acc: 0.279000
# (Iteration 81 / 200) loss: 1.949066
# (Iteration 91 / 200) loss: 1.861190
# (Iteration 101 / 200) loss: 1.797280
# (Iteration 111 / 200) loss: 1.987908
# (Epoch 3 / 5) train acc: 0.351000; val_acc: 0.275000
# (Iteration 121 / 200) loss: 1.890645
# (Iteration 131 / 200) loss: 1.835271
# (Iteration 141 / 200) loss: 2.052773
# (Iteration 151 / 200) loss: 1.685984
# (Epoch 4 / 5) train acc: 0.369000; val_acc: 0.300000
# (Iteration 161 / 200) loss: 1.872801
# (Iteration 171 / 200) loss: 1.667146
# (Iteration 181 / 200) loss: 1.770619
# (Iteration 191 / 200) loss: 1.819564
# (Epoch 5 / 5) train acc: 0.359000; val_acc: 0.296000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 2


# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# [AdaGrad 네트워크가 느리게 학습하는 이유는 학습이 진행될 수록 변화량이 커짐에 따라 적응적 학습률이 점차 낮아지기 때문에 최적화에 도착하기 전 학습이 느리게 진행되며, 조기 종료 될 가능성도 있다.]
#
# [Adam 같은 경우는 이를 방지하기 위해 모멘텀을 추가한 RMSProp을 섞은 방법이기 때문에, AdaGrad에 비해선 학습이 더 원할하게 진행된다. Adam은 두 개의 모멘텀 파라미터가 존재하는데, 첫 번째는 진행하는 속도에 관성을 주는 것이고 두 번째는 경로의 곡면의 변화량에 따른 적응적 학습률이다. 따라서 모멘텀이 속도에 관성을 주고 학습률을 적응적으로 조절하는 알고리즘을 합친 결과로 매우 넓은 범위를 가진 아키텍처의 서로 다른 신경망에서 잘 작동됩니다.]

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the assignment we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** You might find it useful to complete the `BatchNormalization.ipynb` and `Dropout.ipynb` notebooks before completing this part, since those techniques can help you train powerful models.

# %%
best_model = None
best_val = -1

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Random Search
for i in range(20):
    ws = 10**np.random.uniform(-2, -1)
    lr = 10**np.random.uniform(-5, -2)
    reg = 10**np.random.uniform(-3, 3)
    model = FullyConnectedNet([100, 100], weight_scale=ws, reg= reg)

    solver = Solver(model, data,
                    num_epochs=10, batch_size=200,
                    update_rule='adam',
                    optim_config={
                      'learning_rate': lr
                    },
                    verbose=False)
    solver.train()
    val_accuracy = solver.best_val_acc
    if best_val < val_accuracy:
        best_val = val_accuracy
        best_model = model
    # Print results
    print('lr %e ws %e reg %e val accuracy: %f' % (
                lr, ws, reg, val_accuracy))
print('best validation accuracy achieved: %f' % best_val)
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# lr 5.341142e-03 ws 3.727288e-02 reg 1.067335e-01 val accuracy: 0.134000
# lr 1.046177e-05 ws 2.726739e-02 reg 1.802641e-02 val accuracy: 0.413000
# lr 3.439200e-03 ws 5.357101e-02 reg 9.881578e-01 val accuracy: 0.318000
# lr 2.097592e-05 ws 2.146823e-02 reg 2.026629e+01 val accuracy: 0.193000
# lr 1.528702e-04 ws 5.134256e-02 reg 4.210737e-03 val accuracy: 0.429000
# lr 2.544328e-05 ws 3.922263e-02 reg 1.302114e+01 val accuracy: 0.281000
# lr 5.338916e-03 ws 2.626527e-02 reg 3.872236e-03 val accuracy: 0.119000
# lr 4.679773e-03 ws 4.342325e-02 reg 2.111122e-01 val accuracy: 0.276000
# lr 3.900609e-05 ws 2.742660e-02 reg 1.421887e-02 val accuracy: 0.487000
# lr 1.937470e-04 ws 5.581349e-02 reg 1.923677e-03 val accuracy: 0.438000
# lr 2.050772e-03 ws 4.486615e-02 reg 6.119237e-01 val accuracy: 0.354000
# lr 5.182401e-05 ws 4.876848e-02 reg 1.120345e+01 val accuracy: 0.292000
# lr 1.054119e-03 ws 5.435809e-02 reg 8.955280e-02 val accuracy: 0.445000
# lr 1.207360e-04 ws 1.673454e-02 reg 1.965926e+00 val accuracy: 0.347000
# lr 8.069985e-03 ws 8.999993e-02 reg 1.719948e+02 val accuracy: 0.124000
# lr 1.958005e-03 ws 4.552248e-02 reg 1.651854e+01 val accuracy: 0.145000
# lr 1.012147e-04 ws 1.318375e-02 reg 2.181904e-03 val accuracy: 0.520000
# lr 3.026755e-05 ws 2.906811e-02 reg 2.159534e-02 val accuracy: 0.495000
# lr 1.399667e-04 ws 1.958824e-02 reg 3.663249e-03 val accuracy: 0.540000
# lr 6.680901e-03 ws 6.186304e-02 reg 3.673145e+01 val accuracy: 0.150000
# best validation accuracy achieved: 0.540000

# %%
best_lr = 7.107265e-05
best_ws = 1.177946e-02

best_model = FullyConnectedNet([128, 128, 80, 80], weight_scale=best_ws,
                                  dtype=np.float64)

solver = Solver(best_model, data,
                num_epochs=5, batch_size=200,
                update_rule='adam',
                optim_config={
                'learning_rate': best_lr,
                },
                verbose=True)
solver.train()
print("BEST VALID ACC: %f" % solver.best_val_acc)
# Out:
# (Iteration 1 / 1225) loss: 2.302498
# (Epoch 0 / 5) train acc: 0.147000; val_acc: 0